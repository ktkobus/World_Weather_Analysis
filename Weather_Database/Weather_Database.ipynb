# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_current_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
    
    # If an error is experienced, skip the city
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | nongan
# Processing Record 3 of Set 1 | bonthe
# Processing Record 4 of Set 1 | florence
# Processing Record 5 of Set 1 | celestun
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | storm lake
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | san cristobal
# Processing Record 11 of Set 1 | batagay-alyta
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | coquimbo
# Processing Record 14 of Set 1 | guerrero negro
# Processing Record 15 of Set 1 | waddan
# Processing Record 16 of Set 1 | lagoa
# Processing Record 17 of Set 1 | kawalu
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | asau
# Processing Record 21 of Set 1 | nefteyugansk
# Processing Record 22 of Set 1 | evans
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | pochutla
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | hit
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | gorontalo
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | san patricio
# Processing Record 35 of Set 1 | finote selam
# Processing Record 36 of Set 1 | betioky
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | bay roberts
# Processing Record 42 of Set 1 | wonthaggi
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | tuy hoa
# Processing Record 47 of Set 1 | quatre cocos
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 2 | zeitz
# Processing Record 2 of Set 2 | buala
# Processing Record 3 of Set 2 | ust-kut
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | leisure city
# Processing Record 6 of Set 2 | raga
# Processing Record 7 of Set 2 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 2 | katangli
# Processing Record 9 of Set 2 | alice springs
# Processing Record 10 of Set 2 | khandbari
# Processing Record 11 of Set 2 | nome
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | biak
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | tabiauea
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 2 | jiancheng
# Processing Record 20 of Set 2 | maceio
# Processing Record 21 of Set 2 | ketchikan
# Processing Record 22 of Set 2 | hualmay
# Processing Record 23 of Set 2 | kalmunai
# Processing Record 24 of Set 2 | berlevag
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | solsvik
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | sola
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | pontianak
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | nhulunbuy
# Processing Record 35 of Set 2 | ostrovnoy
# Processing Record 36 of Set 2 | labuhan
# Processing Record 37 of Set 2 | biltine
# Processing Record 38 of Set 2 | cabo san lucas
# Processing Record 39 of Set 2 | coihaique
# Processing Record 40 of Set 2 | rehti
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | scottsboro
# Processing Record 43 of Set 2 | kamaishi
# Processing Record 44 of Set 2 | viseu
# Processing Record 45 of Set 2 | kpandu
# Processing Record 46 of Set 2 | tambovka
# Processing Record 47 of Set 2 | broome
# Processing Record 48 of Set 2 | omboue
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | cap malheureux
# Processing Record 1 of Set 3 | yellowknife
# Processing Record 2 of Set 3 | suleja
# Processing Record 3 of Set 3 | erenhot
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | sao filipe
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | cantagallo
# Processing Record 10 of Set 3 | ribas do rio pardo
# Processing Record 11 of Set 3 | nemuro
# Processing Record 12 of Set 3 | broxburn
# Processing Record 13 of Set 3 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 3 | conde
# Processing Record 15 of Set 3 | sao joao da barra
# Processing Record 16 of Set 3 | murdochville
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | xinxiang
# Processing Record 19 of Set 3 | merritt
# Processing Record 20 of Set 3 | pilao arcado
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 3 | methoni
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | victoria
# Processing Record 26 of Set 3 | zhangye
# Processing Record 27 of Set 3 | kahului
# Processing Record 28 of Set 3 | pathein
# Processing Record 29 of Set 3 | kapoeta
# Processing Record 30 of Set 3 | geraldton
# Processing Record 31 of Set 3 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 3 | port hedland
# Processing Record 33 of Set 3 | florida ridge
# Processing Record 34 of Set 3 | mahanje
# Processing Record 35 of Set 3 | verkhnevilyuysk
# Processing Record 36 of Set 3 | praia
# Processing Record 37 of Set 3 | arraial do cabo
# Processing Record 38 of Set 3 | rabat
# Processing Record 39 of Set 3 | taltal
# Processing Record 40 of Set 3 | zanjan
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | ginda
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | georgetown
# Processing Record 45 of Set 3 | mackay
# Processing Record 46 of Set 3 | koygorodok
# Processing Record 47 of Set 3 | potzu
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 3 | portland
# Processing Record 49 of Set 3 | port blair
# Processing Record 50 of Set 3 | rantauprapat
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | lima
# Processing Record 3 of Set 4 | korla
# Processing Record 4 of Set 4 | kasongo-lunda
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 4 | kurskaya
# Processing Record 9 of Set 4 | santa catarina de tepehuanes
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | linhares
# Processing Record 12 of Set 4 | taoudenni
# Processing Record 13 of Set 4 | salalah
# Processing Record 14 of Set 4 | fort nelson
# Processing Record 15 of Set 4 | fortuna
# Processing Record 16 of Set 4 | la ronge
# Processing Record 17 of Set 4 | belmonte
# Processing Record 18 of Set 4 | santa cruz
# Processing Record 19 of Set 4 | parede
# Processing Record 20 of Set 4 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 4 | nuuk
# Processing Record 22 of Set 4 | itanagar
# Processing Record 23 of Set 4 | joshimath
# Processing Record 24 of Set 4 | kuching
# Processing Record 25 of Set 4 | kitui
# Processing Record 26 of Set 4 | lanskroun
# Processing Record 27 of Set 4 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 4 | rawson
# Processing Record 29 of Set 4 | kavaratti
# Processing Record 30 of Set 4 | belyy yar
# Processing Record 31 of Set 4 | hirara
# Processing Record 32 of Set 4 | tsumeb
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | kiama
# Processing Record 35 of Set 4 | aktau
# Processing Record 36 of Set 4 | banswada
# Processing Record 37 of Set 4 | burkhala
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 4 | aklavik
# Processing Record 39 of Set 4 | sept-iles
# Processing Record 40 of Set 4 | krasnyy chikoy
# Processing Record 41 of Set 4 | claresholm
# Processing Record 42 of Set 4 | curup
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | touros
# Processing Record 45 of Set 4 | kaitangata
# Processing Record 46 of Set 4 | mareeba
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | hearst
# Processing Record 49 of Set 4 | stornoway
# Processing Record 50 of Set 4 | faro
# Processing Record 1 of Set 5 | bolobo
# Processing Record 2 of Set 5 | boca do acre
# Processing Record 3 of Set 5 | chicama
# Processing Record 4 of Set 5 | grindavik
# Processing Record 5 of Set 5 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | lodwar
# Processing Record 8 of Set 5 | yar-sale
# Processing Record 9 of Set 5 | hashtgerd
# Processing Record 10 of Set 5 | chaman
# Processing Record 11 of Set 5 | kolo
# Processing Record 12 of Set 5 | port macquarie
# Processing Record 13 of Set 5 | bull savanna
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | nishihara
# Processing Record 16 of Set 5 | nara
# Processing Record 17 of Set 5 | dukat
# Processing Record 18 of Set 5 | yerbogachen
# Processing Record 19 of Set 5 | yarkovo
# Processing Record 20 of Set 5 | rehoboth
# Processing Record 21 of Set 5 | namatanai
# Processing Record 22 of Set 5 | guilin
# Processing Record 23 of Set 5 | aden
# Processing Record 24 of Set 5 | jacmel
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | barcelos
# Processing Record 27 of Set 5 | tazmalt
# Processing Record 28 of Set 5 | tiksi
# Processing Record 29 of Set 5 | country club
# Processing Record 30 of Set 5 | oistins
# Processing Record 31 of Set 5 | colares
# Processing Record 32 of Set 5 | flin flon
# Processing Record 33 of Set 5 | pangody
# Processing Record 34 of Set 5 | bur gabo
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 5 | kamenka
# Processing Record 36 of Set 5 | meulaboh
# Processing Record 37 of Set 5 | tartagal
# Processing Record 38 of Set 5 | dzhusaly
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 5 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 5 | hithadhoo
# Processing Record 41 of Set 5 | tautira
# Processing Record 42 of Set 5 | souillac
# Processing Record 43 of Set 5 | mehamn
# Processing Record 44 of Set 5 | sambava
# Processing Record 45 of Set 5 | lasa
# Processing Record 46 of Set 5 | palmer
# Processing Record 47 of Set 5 | cherskiy
# Processing Record 48 of Set 5 | vila franca do campo
# Processing Record 49 of Set 5 | kununurra
# Processing Record 50 of Set 5 | galapa
# Processing Record 1 of Set 6 | cayenne
# Processing Record 2 of Set 6 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 6 | yinchuan
# Processing Record 4 of Set 6 | rungata
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 6 | kouroussa
# Processing Record 6 of Set 6 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 6 | pevek
# Processing Record 8 of Set 6 | maun
# Processing Record 9 of Set 6 | zhigansk
# Processing Record 10 of Set 6 | nipawin
# Processing Record 11 of Set 6 | puerto escondido
# Processing Record 12 of Set 6 | mumford
# Processing Record 13 of Set 6 | cheuskiny
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 6 | wicklow
# Processing Record 15 of Set 6 | ajdabiya
# Processing Record 16 of Set 6 | itabera
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | jalu
# Processing Record 19 of Set 6 | qiongshan
# Processing Record 20 of Set 6 | the valley
# Processing Record 21 of Set 6 | butembo
# Processing Record 22 of Set 6 | leningradskiy
# Processing Record 23 of Set 6 | hede
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | bonavista
# Processing Record 26 of Set 6 | lata
# Processing Record 27 of Set 6 | matara
# Processing Record 28 of Set 6 | dikson
# Processing Record 29 of Set 6 | trinidad
# Processing Record 30 of Set 6 | samarai
# Processing Record 31 of Set 6 | tacoronte
# Processing Record 32 of Set 6 | khormuj
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 6 | stepnyak
# Processing Record 34 of Set 6 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 6 | kapaa
# Processing Record 36 of Set 6 | mnogovershinnyy
# Processing Record 37 of Set 6 | aloleng
# Processing Record 38 of Set 6 | anloga
# Processing Record 39 of Set 6 | mendahara
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 6 | samfya
# Processing Record 42 of Set 6 | jiayuguan
# Processing Record 43 of Set 6 | amapa
# Processing Record 44 of Set 6 | matiri
# Processing Record 45 of Set 6 | gat
# Processing Record 46 of Set 6 | brae
# Processing Record 47 of Set 6 | brookings
# Processing Record 48 of Set 6 | praia da vitoria
# Processing Record 49 of Set 6 | qaanaaq
# Processing Record 50 of Set 6 | saint-augustin
# Processing Record 1 of Set 7 | panshi
# Processing Record 2 of Set 7 | vestmannaeyjar
# Processing Record 3 of Set 7 | smoky lake
# Processing Record 4 of Set 7 | lorengau
# Processing Record 5 of Set 7 | bria
# Processing Record 6 of Set 7 | kazalinsk
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | san policarpo
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | auki
# Processing Record 11 of Set 7 | longyearbyen
# Processing Record 12 of Set 7 | kavieng
# Processing Record 13 of Set 7 | itarema
# Processing Record 14 of Set 7 | mar del plata
# Processing Record 15 of Set 7 | ahipara
# Processing Record 16 of Set 7 | san jeronimo
# Processing Record 17 of Set 7 | te anau
# Processing Record 18 of Set 7 | balkhash
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | iaciara
# Processing Record 21 of Set 7 | kilindoni
# Processing Record 22 of Set 7 | quelimane
# Processing Record 23 of Set 7 | vredendal
# Processing Record 24 of Set 7 | atoyac
# Processing Record 25 of Set 7 | ozernovskiy
# Processing Record 26 of Set 7 | xuddur
# Processing Record 27 of Set 7 | torbay
# Processing Record 28 of Set 7 | vardo
# Processing Record 29 of Set 7 | nenjiang
# Processing Record 30 of Set 7 | batagay
# Processing Record 31 of Set 7 | seydi
# Processing Record 32 of Set 7 | charlestown
# Processing Record 33 of Set 7 | sakata
# Processing Record 34 of Set 7 | fairbanks
# Processing Record 35 of Set 7 | caravelas
# Processing Record 36 of Set 7 | aykhal
# Processing Record 37 of Set 7 | kodinsk
# Processing Record 38 of Set 7 | otjiwarongo
# Processing Record 39 of Set 7 | menomonie
# Processing Record 40 of Set 7 | fez
# Processing Record 41 of Set 7 | kodiak
# Processing Record 42 of Set 7 | sitka
# Processing Record 43 of Set 7 | la esperanza
# Processing Record 44 of Set 7 | lewiston
# Processing Record 45 of Set 7 | phan thiet
# Processing Record 46 of Set 7 | riyadh
# Processing Record 47 of Set 7 | shingu
# Processing Record 48 of Set 7 | oriximina
# Processing Record 49 of Set 7 | simbahan
# Processing Record 50 of Set 7 | shimonoseki
# Processing Record 1 of Set 8 | boende
# Processing Record 2 of Set 8 | mutare
# Processing Record 3 of Set 8 | fiumicino
# Processing Record 4 of Set 8 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 8 | shelton
# Processing Record 6 of Set 8 | chifeng
# Processing Record 7 of Set 8 | naze
# Processing Record 8 of Set 8 | lesozavodsk
# Processing Record 9 of Set 8 | mezen
# Processing Record 10 of Set 8 | kralendijk
# Processing Record 11 of Set 8 | adrar
# Processing Record 12 of Set 8 | timbiqui
# Processing Record 13 of Set 8 | poum
# Processing Record 14 of Set 8 | athabasca
# Processing Record 15 of Set 8 | harper
# Processing Record 16 of Set 8 | salazie
# Processing Record 17 of Set 8 | gunjur
# Processing Record 18 of Set 8 | harnoli
# Processing Record 19 of Set 8 | kostroma
# Processing Record 20 of Set 8 | vitim
# Processing Record 21 of Set 8 | pontypool
# Processing Record 22 of Set 8 | hawera
# Processing Record 23 of Set 8 | padang
# Processing Record 24 of Set 8 | burnie
# Processing Record 25 of Set 8 | visby
# Processing Record 26 of Set 8 | mamonit
# Processing Record 27 of Set 8 | vawkavysk
# Processing Record 28 of Set 8 | kalyazin
# Processing Record 29 of Set 8 | bayeux
# Processing Record 30 of Set 8 | nizhniy kuranakh
# Processing Record 31 of Set 8 | sao raimundo nonato
# Processing Record 32 of Set 8 | ahuimanu
# Processing Record 33 of Set 8 | alihe
# Processing Record 34 of Set 8 | christchurch
# Processing Record 35 of Set 8 | ruatoria
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 8 | tazovskiy
# Processing Record 37 of Set 8 | smolenka
# Processing Record 38 of Set 8 | vao
# Processing Record 39 of Set 8 | kijang
# Processing Record 40 of Set 8 | thinadhoo
# Processing Record 41 of Set 8 | kyren
# Processing Record 42 of Set 8 | blarney
# Processing Record 43 of Set 8 | bethel
# Processing Record 44 of Set 8 | beringovskiy
# Processing Record 45 of Set 8 | campbell river
# Processing Record 46 of Set 8 | manadhoo
# Processing Record 47 of Set 8 | yaya
# Processing Record 48 of Set 8 | kuala lipis
# Processing Record 49 of Set 8 | paucartambo
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 8 | khonuu
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 9 | ancud
# Processing Record 2 of Set 9 | srandakan
# Processing Record 3 of Set 9 | doctor arroyo
# Processing Record 4 of Set 9 | general pico
# Processing Record 5 of Set 9 | khulna
# Processing Record 6 of Set 9 | kurilsk
# Processing Record 7 of Set 9 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 9 | khasan
# Processing Record 9 of Set 9 | ondorhaan
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 9 | dalen
# Processing Record 11 of Set 9 | kiboga
# Processing Record 12 of Set 9 | halalo
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 9 | san juan
# Processing Record 14 of Set 9 | bilma
# Processing Record 15 of Set 9 | trelew
# Processing Record 16 of Set 9 | chulman
# Processing Record 17 of Set 9 | tokur
# Processing Record 18 of Set 9 | makung
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 9 | tocopilla
# Processing Record 20 of Set 9 | yulara
# Processing Record 21 of Set 9 | codrington
# Processing Record 22 of Set 9 | punta alta
# Processing Record 23 of Set 9 | makakilo city
# Processing Record 24 of Set 9 | olga
# Processing Record 25 of Set 9 | ust-maya
# Processing Record 26 of Set 9 | birobidzhan
# Processing Record 27 of Set 9 | laizhou
# Processing Record 28 of Set 9 | esil
# Processing Record 29 of Set 9 | rjukan
# Processing Record 30 of Set 9 | tiruchchendur
# Processing Record 31 of Set 9 | vostok
# Processing Record 32 of Set 9 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 9 | sao felix do xingu
# Processing Record 34 of Set 9 | boguchany
# Processing Record 35 of Set 9 | bandarbeyla
# Processing Record 36 of Set 9 | sarno
# Processing Record 37 of Set 9 | necochea
# Processing Record 38 of Set 9 | verkhovazhye
# Processing Record 39 of Set 9 | kollumerland
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 9 | beyneu
# Processing Record 41 of Set 9 | rocha
# Processing Record 42 of Set 9 | manuk mangkaw
# Processing Record 43 of Set 9 | kavadarci
# Processing Record 44 of Set 9 | sokoni
# Processing Record 45 of Set 9 | santiago de cao
# Processing Record 46 of Set 9 | libertador general san martin
# Processing Record 47 of Set 9 | airai
# Processing Record 48 of Set 9 | mopipi
# Processing Record 49 of Set 9 | kehtna
# Processing Record 50 of Set 9 | eyl
# Processing Record 1 of Set 10 | zedelgem
# Processing Record 2 of Set 10 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 10 | morros
# Processing Record 4 of Set 10 | aswan
# Processing Record 5 of Set 10 | chau doc
# Processing Record 6 of Set 10 | saint pete beach
# Processing Record 7 of Set 10 | monrovia
# Processing Record 8 of Set 10 | hambantota
# Processing Record 9 of Set 10 | yumen
# Processing Record 10 of Set 10 | linxia
# Processing Record 11 of Set 10 | araripe
# Processing Record 12 of Set 10 | vryburg
# Processing Record 13 of Set 10 | takoradi
# Processing Record 14 of Set 10 | skjervoy
# Processing Record 15 of Set 10 | nouakchott
# Processing Record 16 of Set 10 | mangai
# Processing Record 17 of Set 10 | kutum
# Processing Record 18 of Set 10 | enshi
# Processing Record 19 of Set 10 | cidreira
# Processing Record 20 of Set 10 | mankera
# Processing Record 21 of Set 10 | uaua
# Processing Record 22 of Set 10 | villa carlos paz
# Processing Record 23 of Set 10 | kieta
# Processing Record 24 of Set 10 | verkhoyansk
# Processing Record 25 of Set 10 | moose factory
# Processing Record 26 of Set 10 | camacari
# Processing Record 27 of Set 10 | mahon
# Processing Record 28 of Set 10 | san quintin
# Processing Record 29 of Set 10 | kudahuvadhoo
# Processing Record 30 of Set 10 | piacabucu
# Processing Record 31 of Set 10 | verkhniy baskunchak
# Processing Record 32 of Set 10 | palm springs
# Processing Record 33 of Set 10 | college
# Processing Record 34 of Set 10 | anadyr
# Processing Record 35 of Set 10 | louisbourg
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 10 | vila velha
# Processing Record 37 of Set 10 | valparaiso
# Processing Record 38 of Set 10 | chake chake
# Processing Record 39 of Set 10 | baykit
# Processing Record 40 of Set 10 | luquillo
# Processing Record 41 of Set 10 | san ramon
# Processing Record 42 of Set 10 | puga
# Processing Record 43 of Set 10 | katsuura
# Processing Record 44 of Set 10 | vanavara
# Processing Record 45 of Set 10 | grajau
# Processing Record 46 of Set 10 | lively
# Processing Record 47 of Set 10 | tilichiki
# Processing Record 48 of Set 10 | suntar
# Processing Record 49 of Set 10 | oktyabrskiy
# Processing Record 50 of Set 10 | phan rang
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 11 | sandwick
# Processing Record 2 of Set 11 | barmer
# Processing Record 3 of Set 11 | teguldet
# Processing Record 4 of Set 11 | ust-nera
# Processing Record 5 of Set 11 | sarlat-la-caneda
# Processing Record 6 of Set 11 | saint-pierre
# Processing Record 7 of Set 11 | belaya gora
# Processing Record 8 of Set 11 | evensk
# Processing Record 9 of Set 11 | seoul
# Processing Record 10 of Set 11 | manama
# Processing Record 11 of Set 11 | whitehorse
# Processing Record 12 of Set 11 | sikandra
# Processing Record 13 of Set 11 | swabi
# Processing Record 14 of Set 11 | yamethin
# Processing Record 15 of Set 11 | labuan
# Processing Record 16 of Set 11 | norsup
# Processing Record 17 of Set 11 | danjiangkou
# Processing Record 18 of Set 11 | gaya
# Processing Record 19 of Set 11 | huarmey
# Processing Record 20 of Set 11 | pangnirtung
# Processing Record 21 of Set 11 | ngunguru
# Processing Record 22 of Set 11 | dzilam gonzalez
# Processing Record 23 of Set 11 | port lincoln
# Processing Record 24 of Set 11 | cocoa
# Processing Record 25 of Set 11 | volkermarkt
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 11 | hanzhong
# Processing Record 27 of Set 11 | porto novo
# Processing Record 28 of Set 11 | kargasok
# Processing Record 29 of Set 11 | akdepe
# Processing Record 30 of Set 11 | dubai
# Processing Record 31 of Set 11 | ishigaki
# Processing Record 32 of Set 11 | nordlingen
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 11 | tiznit
# Processing Record 34 of Set 11 | halifax
# Processing Record 35 of Set 11 | moranbah
# Processing Record 36 of Set 11 | camocim
# Processing Record 37 of Set 11 | kimbe
# Processing Record 38 of Set 11 | westport
# Processing Record 39 of Set 11 | east stroudsburg
# Processing Record 40 of Set 11 | saint-joseph
# Processing Record 41 of Set 11 | comodoro rivadavia
# Processing Record 42 of Set 11 | chissamba
# Processing Record 43 of Set 11 | la tuque
# Processing Record 44 of Set 11 | bennington
# Processing Record 45 of Set 11 | bodmin
# Processing Record 46 of Set 11 | taksimo
# Processing Record 47 of Set 11 | tessalit
# Processing Record 48 of Set 11 | pombia
# Processing Record 49 of Set 11 | angoche
# Processing Record 50 of Set 11 | ayagoz
# Processing Record 1 of Set 12 | vyborg
# Processing Record 2 of Set 12 | zarate
# Processing Record 3 of Set 12 | watrous
# Processing Record 4 of Set 12 | isangel
# Processing Record 5 of Set 12 | kibakwe
# Processing Record 6 of Set 12 | brewster
# Processing Record 7 of Set 12 | carmen
# Processing Record 8 of Set 12 | galiwinku
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 12 | voi
# Processing Record 10 of Set 12 | tangier
# Processing Record 11 of Set 12 | siniscola
# Processing Record 12 of Set 12 | popondetta
# Processing Record 13 of Set 12 | tecoanapa
# Processing Record 14 of Set 12 | ambilobe
# Processing Record 15 of Set 12 | havelock
# Processing Record 16 of Set 12 | barabinsk
# Processing Record 17 of Set 12 | sembe
# Processing Record 18 of Set 12 | buraydah
# Processing Record 19 of Set 12 | saldanha
# Processing Record 20 of Set 12 | high level
# Processing Record 21 of Set 12 | havoysund
# Processing Record 22 of Set 12 | kapit
# Processing Record 23 of Set 12 | clyde river
# Processing Record 24 of Set 12 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 12 | tandil
# Processing Record 26 of Set 12 | haines junction
# Processing Record 27 of Set 12 | skalistyy
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 12 | jiuquan
# Processing Record 29 of Set 12 | alamogordo
# Processing Record 30 of Set 12 | ciudad del maiz
# Processing Record 31 of Set 12 | markova
# Processing Record 32 of Set 12 | mandi bahauddin
# Processing Record 33 of Set 12 | pijijiapan
# Processing Record 34 of Set 12 | gediz
# Processing Record 35 of Set 12 | batemans bay
# Processing Record 36 of Set 12 | karoi
# Processing Record 37 of Set 12 | tutora
# Processing Record 38 of Set 12 | weston
# Processing Record 39 of Set 12 | semnan
# Processing Record 40 of Set 12 | tual
# Processing Record 41 of Set 12 | pisco
# Processing Record 42 of Set 12 | sioux lookout
# Processing Record 43 of Set 12 | kupang
# Processing Record 44 of Set 12 | khani
# Processing Record 45 of Set 12 | key west
# Processing Record 46 of Set 12 | faaa
# Processing Record 47 of Set 12 | olafsvik
# Processing Record 48 of Set 12 | byron bay
# Processing Record 49 of Set 12 | kumano
# Processing Record 50 of Set 12 | capitan bado
# Processing Record 1 of Set 13 | san carlos
# Processing Record 2 of Set 13 | kirya
# Processing Record 3 of Set 13 | kosonsoy
# Processing Record 4 of Set 13 | chiredzi
# Processing Record 5 of Set 13 | sao jose da coroa grande
# Processing Record 6 of Set 13 | zeya
# Processing Record 7 of Set 13 | shatki
# Processing Record 8 of Set 13 | troutdale
# Processing Record 9 of Set 13 | high rock
# Processing Record 10 of Set 13 | san nicolas
# Processing Record 11 of Set 13 | catumbela
# Processing Record 12 of Set 13 | bardsir
# Processing Record 13 of Set 13 | togur
# Processing Record 14 of Set 13 | husavik
# Processing Record 15 of Set 13 | hastings
# Processing Record 16 of Set 13 | dubrovnik
# Processing Record 17 of Set 13 | viedma
# Processing Record 18 of Set 13 | terenos
# Processing Record 19 of Set 13 | awbari
# Processing Record 20 of Set 13 | bolshoy tsaryn
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 13 | umm kaddadah
# Processing Record 22 of Set 13 | general roca
# Processing Record 23 of Set 13 | hovd
# Processing Record 24 of Set 13 | tibiri
# Processing Record 25 of Set 13 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 13 | tarija
# Processing Record 27 of Set 13 | dingle
# Processing Record 28 of Set 13 | gimli
# Processing Record 29 of Set 13 | kedrovyy
# Processing Record 30 of Set 13 | muroto
# Processing Record 31 of Set 13 | aqtobe
# Processing Record 32 of Set 13 | dillon
# Processing Record 33 of Set 13 | grand gaube
# Processing Record 34 of Set 13 | kumba
# Processing Record 35 of Set 13 | linfen
# Processing Record 36 of Set 13 | ormos korthiou
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 13 | borgarnes
# Processing Record 38 of Set 13 | mutoko
# Processing Record 39 of Set 13 | chambas
# Processing Record 40 of Set 13 | filingue
# Processing Record 41 of Set 13 | sahrak
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 13 | richards bay
# Processing Record 43 of Set 13 | yakeshi
# Processing Record 44 of Set 13 | sadao
# Processing Record 45 of Set 13 | kadyy
# Processing Record 46 of Set 13 | moree
# Processing Record 47 of Set 13 | boa vista
# Processing Record 48 of Set 13 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 13 | nabire
# Processing Record 50 of Set 13 | penzance
# Processing Record 1 of Set 14 | plettenberg bay
# Processing Record 2 of Set 14 | ola
# Processing Record 3 of Set 14 | margate
# Processing Record 4 of Set 14 | port shepstone
# Processing Record 5 of Set 14 | shiyan
# Processing Record 6 of Set 14 | nizhniy odes
# Processing Record 7 of Set 14 | san-pedro
# Processing Record 8 of Set 14 | alta floresta
# Processing Record 9 of Set 14 | saint anthony
# Processing Record 10 of Set 14 | samoded
# Processing Record 11 of Set 14 | afmadu
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 14 | krasnoarmeysk
# Processing Record 13 of Set 14 | gornopravdinsk
# Processing Record 14 of Set 14 | cockburn town
# Processing Record 15 of Set 14 | nisia floresta
# Processing Record 16 of Set 14 | maldonado
# Processing Record 17 of Set 14 | calbuco
# Processing Record 18 of Set 14 | reconquista
# Processing Record 19 of Set 14 | daru
# Processing Record 20 of Set 14 | prado
# Processing Record 21 of Set 14 | constantine
# Processing Record 22 of Set 14 | acapulco
# Processing Record 23 of Set 14 | narsaq
# Processing Record 24 of Set 14 | morant bay
# Processing Record 25 of Set 14 | inuvik
# Processing Record 26 of Set 14 | xiongzhou
# Processing Record 27 of Set 14 | komsomolskiy
# Processing Record 28 of Set 14 | bathsheba
# Processing Record 29 of Set 14 | karratha
# Processing Record 30 of Set 14 | champerico
# Processing Record 31 of Set 14 | xining
# Processing Record 32 of Set 14 | marion
# Processing Record 33 of Set 14 | semirom
# Processing Record 34 of Set 14 | rabo de peixe
# Processing Record 35 of Set 14 | nantucket
# Processing Record 36 of Set 14 | kruisfontein
# Processing Record 37 of Set 14 | juegang
# Processing Record 38 of Set 14 | jieshi
# Processing Record 39 of Set 14 | svetlogorsk
# Processing Record 40 of Set 14 | naron
# Processing Record 41 of Set 14 | camopi
# Processing Record 42 of Set 14 | chikoy
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 14 | sorland
# Processing Record 44 of Set 14 | huitzuco
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 14 | tutoia
# Processing Record 46 of Set 14 | turtkul
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 14 | moen
# Processing Record 48 of Set 14 | rumonge
# Processing Record 49 of Set 14 | plessisville
# Processing Record 50 of Set 14 | edgewater
# Processing Record 1 of Set 15 | pelym
# Processing Record 2 of Set 15 | kizlyar
# Processing Record 3 of Set 15 | haradok
# Processing Record 4 of Set 15 | moron
# Processing Record 5 of Set 15 | uinskoye
# Processing Record 6 of Set 15 | huilong
# Processing Record 7 of Set 15 | honningsvag
# Processing Record 8 of Set 15 | zarya
# Processing Record 9 of Set 15 | berdigestyakh
# Processing Record 10 of Set 15 | mao
# Processing Record 11 of Set 15 | erzin
# Processing Record 12 of Set 15 | paamiut
# Processing Record 13 of Set 15 | bushehr
# Processing Record 14 of Set 15 | saryg-sep
# Processing Record 15 of Set 15 | etla
# Processing Record 16 of Set 15 | launceston
# Processing Record 17 of Set 15 | cururupu
# Processing Record 18 of Set 15 | puerto carreno
# Processing Record 19 of Set 15 | nyagan
# Processing Record 20 of Set 15 | little chute
# Processing Record 21 of Set 15 | zhuhai
# Processing Record 22 of Set 15 | catalao
# Processing Record 23 of Set 15 | ponta delgada
# Processing Record 24 of Set 15 | bitkine
# Processing Record 25 of Set 15 | grand-santi
# Processing Record 26 of Set 15 | biloela
# Processing Record 27 of Set 15 | indiana
# Processing Record 28 of Set 15 | mamontovo
# Processing Record 29 of Set 15 | oktyabrskoye
# Processing Record 30 of Set 15 | adre
# Processing Record 31 of Set 15 | broken hill
# Processing Record 32 of Set 15 | mingshui
# Processing Record 33 of Set 15 | zerbst
# Processing Record 34 of Set 15 | nouadhibou
# Processing Record 35 of Set 15 | lumding
# Processing Record 36 of Set 15 | wanaka
# Processing Record 37 of Set 15 | outlook
# Processing Record 38 of Set 15 | grand centre
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 15 | olovyannaya
# Processing Record 40 of Set 15 | dakoro
# Processing Record 41 of Set 15 | todos santos
# Processing Record 42 of Set 15 | araouane
# Processing Record 43 of Set 15 | hervey bay
# Processing Record 44 of Set 15 | berkakit
# Processing Record 45 of Set 15 | kristiansund
# Processing Record 46 of Set 15 | karamken
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 15 | banda aceh
# Processing Record 48 of Set 15 | gilgit
# Processing Record 49 of Set 15 | cabedelo
# Processing Record 50 of Set 15 | udachnyy
# Processing Record 1 of Set 16 | warqla
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 16 | viligili
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 16 | atherton
# Processing Record 4 of Set 16 | patrocinio
# Processing Record 5 of Set 16 | sur
# Processing Record 6 of Set 16 | bud
# Processing Record 7 of Set 16 | saint-georges
# Processing Record 8 of Set 16 | manicore
# Processing Record 9 of Set 16 | manta
# Processing Record 10 of Set 16 | qui nhon
# Processing Record 11 of Set 16 | dzhebariki-khaya
# Processing Record 12 of Set 16 | san andres
# Processing Record 13 of Set 16 | namibe
# Processing Record 14 of Set 16 | tuatapere
# Processing Record 15 of Set 16 | cooma
# Processing Record 16 of Set 16 | sandomierz
# Processing Record 17 of Set 16 | amahai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jamestown  42.0970  -79.2353     36.72        50           0
# 1         Nongan  44.3820  125.1685     14.14        39           5
# 2         Bonthe   7.5264  -12.5050     74.48        90          13
# 3       Florence  43.7667   11.2500     52.59        80          75
# 4       Celestun  20.8667  -90.4000     71.94        66          58
# 5         Atuona  -9.8000 -139.0333     78.28        76          11
# 6     Storm Lake  42.6411  -95.2097     33.30       100         100
# 7         Avarua -21.2078 -159.7750     82.45        65          75
# 8        Rikitea -23.1203 -134.9692     77.83        69           2
# 9  San Cristobal   7.7669  -72.2250     68.18        94          55
#
#    Wind Speed Country Current Description
# 0        6.91      US           clear sky
# 1       12.30      CN           clear sky
# 2        4.76      SL          few clouds
# 3        2.30      IT       broken clouds
# 4       11.45      MX       broken clouds
# 5       16.98      PF          few clouds
# 6       16.11      US          light snow
# 7        8.05      CK       broken clouds
# 8        6.04      PF           clear sky
# 9        2.42      VE       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jamestown      US  42.0970  -79.2353     36.72        50           0
# 1         Nongan      CN  44.3820  125.1685     14.14        39           5
# 2         Bonthe      SL   7.5264  -12.5050     74.48        90          13
# 3       Florence      IT  43.7667   11.2500     52.59        80          75
# 4       Celestun      MX  20.8667  -90.4000     71.94        66          58
# 5         Atuona      PF  -9.8000 -139.0333     78.28        76          11
# 6     Storm Lake      US  42.6411  -95.2097     33.30       100         100
# 7         Avarua      CK -21.2078 -159.7750     82.45        65          75
# 8        Rikitea      PF -23.1203 -134.9692     77.83        69           2
# 9  San Cristobal      VE   7.7669  -72.2250     68.18        94          55
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1       12.30           clear sky
# 2        4.76          few clouds
# 3        2.30       broken clouds
# 4       11.45       broken clouds
# 5       16.98          few clouds
# 6       16.11          light snow
# 7        8.05       broken clouds
# 8        6.04           clear sky
# 9        2.42       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
